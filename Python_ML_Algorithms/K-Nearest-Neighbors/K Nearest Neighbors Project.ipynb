# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # K Nearest Neighbors Project
#
# Welcome to the KNN Project! This will be a simple project very similar to the lecture, except you'll be given another data set. Go ahead and just follow the directions below.
# ## Import Libraries
# **Import pandas,seaborn, and the usual libraries.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
plt.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# ## Get the Data
# ** Read the 'KNN_Project_Data csv file into a dataframe **

# %%
kdf = pd.read_csv('KNN_Project_Data')

# %%
kdf.head()
# Out:
#                     GWYH         TRAT        TLLZ         IGGA         HYKR  \
# XVPM
# 1636.670614   817.988525  2565.995189  358.347163   550.417491  1618.870897
# 1013.402760   577.587332  2644.141273  280.428203  1161.873391  2084.107872
# 1300.035501   820.518697  2025.854469  525.562292   922.206261  2552.355407
# 1059.347542  1066.866418   612.000041  480.827789   419.467495   685.666983
# 1018.340526  1313.679056   950.622661  724.742174   843.065903  1370.554164
#
#                     EDFS        GUUB         MGJM         JHZC  TARGET CLASS
# XVPM
# 1636.670614  2147.641254  330.727893  1494.878631   845.136088             0
# 1013.402760   853.404981  447.157619  1193.032521   861.081809             1
# 1300.035501   818.676686  845.491492  1968.367513  1647.186291             1
# 1059.347542   852.867810  341.664784  1154.391368  1450.935357             0
# 1018.340526   905.469453  658.118202   539.459350  1899.850792             0

# %% [markdown]
# **Check the head of the dataframe.**

# %%
# Out:
#           XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0  1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1  1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2  1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3  1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4  1018.340526  1313.679056   950.622661  724.742174   843.065903
#
#           HYKR         EDFS        GUUB         MGJM         JHZC  \
# 0  1618.870897  2147.641254  330.727893  1494.878631   845.136088
# 1  2084.107872   853.404981  447.157619  1193.032521   861.081809
# 2  2552.355407   818.676686  845.491492  1968.367513  1647.186291
# 3   685.666983   852.867810  341.664784  1154.391368  1450.935357
# 4  1370.554164   905.469453  658.118202   539.459350  1899.850792
#
#    TARGET CLASS
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0

# %% [markdown]
# # EDA
#
# Since this data is artificial, we'll just do a large pairplot with seaborn.
#
# **Use seaborn on the dataframe to create a pairplot with the hue indicated by the TARGET CLASS column.**

# %%
sns.pairplot(data=kdf,hue='TARGET CLASS',dropna=True)

# %% [markdown]
# # Standardize the Variables
#
# Time to standardize the variables.
#
# ** Import StandardScaler from Scikit learn.**

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ** Create a StandardScaler() object called scaler.**

# %%
scalar = StandardScaler()

# %%
scalar.fit(kdf.drop(labels=['TARGET CLASS'],axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scalar.transform(kdf.drop(labels=['TARGET CLASS'],axis=1))

# %%
sdf = pd.DataFrame(scaled_features,columns=kdf.columns[:-1])

# %%
sdf.head()
# Out:
#        XVPM      GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS  \
# 0  1.568522 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493
# 1 -0.112376 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663
# 2  0.660647 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707
# 3  0.011533  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561
# 4 -0.099059  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644
#
#        GUUB      MGJM      JHZC
# 0 -0.932794  1.008313 -1.069627
# 1 -0.461864  0.258321 -1.041546
# 2  1.149298  2.184784  0.342811
# 3 -0.888557  0.162310 -0.002793
# 4  0.391419 -1.365603  0.787762

# %% [markdown]
# ** Fit scaler to the features.**

# %%
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
# Out:
#        XVPM      GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS  \
# 0  1.568522 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493
# 1 -0.112376 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663
# 2  0.660647 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707
# 3  0.011533  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561
# 4 -0.099059  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644
#
#        GUUB      MGJM      JHZC
# 0 -0.932794  1.008313 -1.069627
# 1 -0.461864  0.258321 -1.041546
# 2  1.149298  2.184784  0.342811
# 3 -0.888557  0.162310 -0.002793
# 4  0.391419 -1.365603  0.787762

# %% [markdown]
# # Train Test Split
#
# **Use train_test_split to split your data into a training set and a testing set.**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(sdf, kdf['TARGET CLASS'], test_size=0.30)

# %% [markdown]
# # Using KNN
#
# **Import KNeighborsClassifier from scikit learn.**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knm = KNeighborsClassifier(n_neighbors=1)

# %%
knm.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# **Create a KNN model instance with n_neighbors=1**

# %% [markdown]
# **Fit this KNN model to the training data.**

# %%
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# # Predictions and Evaluations
# Let's evaluate our KNN model!

# %% [markdown]
# **Use the predict method to predict values using your KNN model and X_test.**

# %%
predicted_values = knm.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,predicted_values))
# Out:
# [[111  53]
#  [ 26 110]]

# %%
print(classification_report(y_test,predicted_values))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.68      0.74       164
#           1       0.67      0.81      0.74       136
#
# avg / total       0.75      0.74      0.74       300

# %% [markdown]
# ** Create a confusion matrix and classification report.**

# %%
# Out:
# [[112  40]
#  [ 34 114]]

# %%
# Out:
#              precision    recall  f1-score   support
#
#           0       0.77      0.74      0.75       152
#           1       0.74      0.77      0.75       148
#
# avg / total       0.75      0.75      0.75       300

# %% [markdown]
# # Choosing a K Value
# Let's go ahead and use the elbow method to pick a good K Value!
#
# ** Create a for loop that trains various KNN models with different k values, then keep track of the error_rate for each of these models with a list. Refer to the lecture if you are confused on this step.**

# %%
error_rate= []
for k in range(1,40):
    knm = KNeighborsClassifier(n_neighbors=k)
    knm.fit(X_train,y_train)
    pred_i = knm.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(6,4))
plt.plot(range(1,40),error_rate,marker='o',markerfacecolor='red',markersize='4',linestyle='dashed')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.title('Error Rate vs. K Value')

# %% [markdown]
# **Now create the following plot using the information from your for loop.**

# %% [markdown]
# ## Retrain with new K Value
#
# **Retrain your model with the best K value (up to you to decide what you want) and re-do the classification report and the confusion matrix.**

# %%
knm = KNeighborsClassifier(n_neighbors=30)
knm.fit(X_train,y_train)
predicted_values = knm.predict(X_test)

# %%
print(confusion_matrix(y_test,predicted_values))
# Out:
# [[134  30]
#  [ 24 112]]

# %%
print(classification_report(y_test,predicted_values))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.82      0.83       164
#           1       0.79      0.82      0.81       136
#
# avg / total       0.82      0.82      0.82       300

# %%
# Out:
# WITH K=30
#
#
# [[127  25]
#  [ 23 125]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.85      0.84      0.84       152
#           1       0.83      0.84      0.84       148
#
# avg / total       0.84      0.84      0.84       300

# %% [markdown]
# # Great Job!
